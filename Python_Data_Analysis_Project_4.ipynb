# %% [markdown]
# #YouTube Link :

# %% [markdown]
# https://youtu.be/89eYAAPyRfo

# %% [markdown]
# #Working on Real Project with Python

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/4. covid_19_data.csv")

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.shape
# Out:
# (321, 6)

# %%
# 1. use: 
#data.count()
# data.isnull().sum

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ##1. Show the number of confirmed, Death and Recoverd cases in each Region.

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered','Deaths'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Confirmed  Recovered  Deaths
# Region
# Afghanistan              1939        252      60
# Albania                   766        455      30
# Algeria                  3848       1702     444
# Andorra                   743        423      42
# Angola                     27          7       2
# ...                       ...        ...     ...
# West Bank and Gaza        344         71       2
# Western Sahara              6          5       0
# Yemen                       6          1       0
# Zambia                     97         54       3
# Zimbabwe                   32          5       4
#
# [187 rows x 3 columns]

# %% [markdown]
# ##2. Remove all the records where Confirmed Cases is less than 10.

# %%
data.Confirmed <10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[~(data.Confirmed <10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data=data[~(data.Confirmed <10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# ##3. In which Region, maximun number of Confirmed cases were recorded?

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Holy See           10
# Gambia             10
# Suriname           10
# Name: Confirmed, Length: 180, dtype: int64

# %% [markdown]
# ##4. In which Region, minimun number of Deaths cases were recorded?

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# ##5. How many Confirmed, Deaths, Recovered cases were reported from india till 29 April 2020 ?

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data[data.Region == "India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == "Afghanistan"]
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252

# %%
data[data.Region == "US"]
# Out:
#           Date                         State  ... Deaths  Recovered
# 181  4/29/2020                       Alabama  ...    256          0
# 182  4/29/2020                        Alaska  ...      9          0
# 186  4/29/2020                       Arizona  ...    308          0
# 187  4/29/2020                      Arkansas  ...     57          0
# 195  4/29/2020                    California  ...   1946          0
# 199  4/29/2020                      Colorado  ...    766          0
# 200  4/29/2020                   Connecticut  ...   2169          0
# 202  4/29/2020                      Delaware  ...    144          0
# 204  4/29/2020  Diamond Princess cruise ship  ...      0          0
# 205  4/29/2020          District of Columbia  ...    205          0
# 208  4/29/2020                       Florida  ...   1218          0
# 213  4/29/2020                       Georgia  ...   1101          0
# 216  4/29/2020                Grand Princess  ...      3          0
# ...

# %% [markdown]
# ##6. A) Sort the entire data wrt No. of Confirmed cases in ascending order.
#
# ---

# %%
data=pd.read_csv("/content/4. covid_19_data.csv")

# %%
data.sort_values(by=['Confirmed'],ascending=True).head(50)
# Out:
#           Date                             State  ... Deaths  Recovered
# 285  4/29/2020                         Recovered  ...      0     120720
# 284  4/29/2020                         Recovered  ...      0      20327
# 203  4/29/2020      Diamond Princess cruise ship  ...      1          0
# 305  4/29/2020                             Tibet  ...      0          1
# 289  4/29/2020         Saint Pierre and Miquelon  ...      0          0
# 184  4/29/2020                          Anguilla  ...      0          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba  ...      0          0
# 272  4/29/2020             Northwest Territories  ...      0          0
# 288  4/29/2020                  Saint Barthelemy  ...      0          6
# 178  4/29/2020                               NaN  ...      0          1
# 194  4/29/2020            British Virgin Islands  ...      1          3
# 177  4/29/2020                               NaN  ...      0          5
# ...

# %% [markdown]
# ##6. B)  Sort the entire data wrt No. of Recovered cases in descending order.

# %%
data.sort_values(by=["Recovered"],ascending= False).head(50)
# Out:
#           Date            State  ... Deaths  Recovered
# 153  4/29/2020              NaN  ...  24275     132929
# 285  4/29/2020        Recovered  ...      0     120720
# 61   4/29/2020              NaN  ...   6467     120400
# 76   4/29/2020              NaN  ...   5957      73791
# 80   4/29/2020              NaN  ...  27682      71252
# 229  4/29/2020            Hubei  ...   4512      63616
# 57   4/29/2020              NaN  ...  24087      48228
# 167  4/29/2020              NaN  ...   3081      44040
# 22   4/29/2020              NaN  ...   5513      34132
# 158  4/29/2020              NaN  ...   1716      22600
# 284  4/29/2020        Recovered  ...      0      20327
# 78   4/29/2020              NaN  ...   1190      13386
# 8    4/29/2020              NaN  ...    580      12779
# 107  4/29/2020              NaN  ...   1732      11423
# 15   4/29/2020              NaN  ...   7501      11283
# 134  4/29/2020              NaN  ...    972      10286
# ...
